# %%
# !jupyter nbconvert --to python test.ipynb --output tannson_fnc
# Out:
# [NbConvertApp] Converting notebook test.ipynb to python
# [NbConvertApp] Writing 6624 bytes to tannson_fnc.py

# %%
# !jupyter nbconvert --to python regex.ipynb --output item_regex
# Out:
# [NbConvertApp] Converting notebook item_regex.ipynb to python
# [NbConvertApp] Writing 20129 bytes to item_regex.py
